# %%
import json
from pprint import pprint

with open('items.json') as data_file:    
    data = json.load(data_file)

# %%
for t in data:
    
    print t['date'][0].lstrip().rstrip(), t['title'][0]
# Out:
# 22 июля 2016, 13:49 Ракеты с лазерным наведением и торпеда не смогли потопить старый американский фрегат
# 22 июля 2016, 14:36 В Челябинске несколько пожилых женщин перекрыли дорогу, чтобы перевести уток
# 22 июля 2016, 14:43 Китайцы проведут первую модификацию генома человека с помощью CRISPR в августе
# 25 июля 2016, 12:13 В ночном клубе во Флориде произошла стрельба
# 29 июля 2016, 03:42 Фото: Авария с утятами
# 28 июля 2016, 05:48 Microsoft выпустил камеру, подбирающую настройки при помощи ИИ
# 22 июля 2016, 15:18 Трюки с шариком
# 25 июля 2016, 12:14 Гигантский аппарат для непрерывной укладки железнодорожных путей
# 28 июля 2016, 23:26 Создатели Prisma выпустили бота для обработки фотографий через Telegram
# 27 июля 2016, 11:17 Xiaomi представила собственный ультрабук
# 27 июля 2016, 22:30 Американские учёные обнаружили у берегов Калифорнии неизвестный науке фиолетовый пузырь
# 26 июля 2016, 11:05 В СК опровергли кражу у петербургского школьника 1,2 миллиона рублей
# ...

# %%
data
# Out:
# [{u'date': [u'\n                                    26 \u0438\u044e\u043d\u044f 2016, 18:21\n                            '],
#   u'title': [u'\u041d\u0430 20-\u043b\u0435\u0442\u0438\u0435 Quake \u0432\u044b\u043f\u0443\u0449\u0435\u043d \u043d\u043e\u0432\u044b\u0439 \u044d\u043f\u0438\u0437\u043e\u0434 \u0434\u043b\u044f \u044d\u0442\u043e\u0439 \u0438\u0433\u0440\u044b']},
#  {u'date': [u'\n                                    26 \u0438\u044e\u043d\u044f 2016, 17:53\n                            '],
#   u'title': [u'\u0421\u0442\u0443\u0434\u0435\u043d\u0442\u044b \u0440\u0430\u0437\u043e\u0433\u043d\u0430\u043b\u0438 \u044d\u043b\u0435\u043a\u0442\u0440\u043e\u043a\u0430\u0440 \u0434\u043e 100 \u043a\u043c/\u0447 \u0437\u0430 1,5 \u0441\u0435\u043a\u0443\u043d\u0434\u044b \u0438 \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u043b\u0438 \u043d\u043e\u0432\u044b\u0439 \u043c\u0438\u0440\u043e\u0432\u043e\u0439 \u0440\u0435\u043a\u043e\u0440\u0434']},
# ...
